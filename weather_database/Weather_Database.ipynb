# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Identify the nearest city for each latitude and longitude combination.

coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
      
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 774

# %%
#Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
#starting URL for weathing map api call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3b3ab0f8a745015731d3dfe5180b08e2

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | pilar
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | kahului
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | high level
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | mopipi
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | palembang
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | los llanos de aridane
# Processing Record 18 of Set 1 | preobrazheniye
# Processing Record 19 of Set 1 | brokopondo
# Processing Record 20 of Set 1 | maine-soroa
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | dongsheng
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | schruns
# Processing Record 27 of Set 1 | bytosh
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | manglaur
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | ibanda
# Processing Record 34 of Set 1 | tambopata
# Processing Record 35 of Set 1 | tocopilla
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | dharchula
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | skibbereen
# Processing Record 40 of Set 1 | juegang
# Processing Record 41 of Set 1 | lozuvatka
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | chokwe
# Processing Record 46 of Set 1 | kamaishi
# Processing Record 47 of Set 1 | wuchi
# Processing Record 48 of Set 1 | tsurib
# Processing Record 49 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 1 | buchanan
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | nikolayevsk-na-amure
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | avera
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | shepsi
# Processing Record 9 of Set 2 | keshan
# City not found. Skipping...
# Processing Record 10 of Set 2 | kirakira
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | mehamn
# Processing Record 14 of Set 2 | kalmunai
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | kodino
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | birao
# Processing Record 22 of Set 2 | nakhon phanom
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | nizhnevartovsk
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | arlit
# Processing Record 27 of Set 2 | aquiraz
# Processing Record 28 of Set 2 | churapcha
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | okhotsk
# Processing Record 32 of Set 2 | kirensk
# Processing Record 33 of Set 2 | lasa
# Processing Record 34 of Set 2 | aketi
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | tessalit
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | braganca
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | boende
# Processing Record 44 of Set 2 | mutoko
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | alta floresta
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | ranghulu
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | siguiri
# Processing Record 3 of Set 3 | qui nhon
# Processing Record 4 of Set 3 | kapit
# Processing Record 5 of Set 3 | mehtar lam
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | santa maria
# Processing Record 11 of Set 3 | sembe
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | bengkulu
# Processing Record 17 of Set 3 | albuquerque
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | adjumani
# Processing Record 20 of Set 3 | lima
# Processing Record 21 of Set 3 | aksu
# Processing Record 22 of Set 3 | dali
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | faya
# Processing Record 25 of Set 3 | shache
# Processing Record 26 of Set 3 | horconcitos
# Processing Record 27 of Set 3 | camapua
# Processing Record 28 of Set 3 | bud
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | namatanai
# Processing Record 34 of Set 3 | egvekinot
# Processing Record 35 of Set 3 | biswan
# Processing Record 36 of Set 3 | cape town
# Processing Record 37 of Set 3 | mount isa
# Processing Record 38 of Set 3 | cayenne
# Processing Record 39 of Set 3 | brindisi
# Processing Record 40 of Set 3 | lazaro cardenas
# Processing Record 41 of Set 3 | gigmoto
# Processing Record 42 of Set 3 | lubao
# Processing Record 43 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | ashta
# Processing Record 46 of Set 3 | karatau
# Processing Record 47 of Set 3 | ushibuka
# Processing Record 48 of Set 3 | mohan
# Processing Record 49 of Set 3 | oreanda
# City not found. Skipping...
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | payson
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | terra santa
# Processing Record 4 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 5 of Set 4 | sovetskiy
# Processing Record 6 of Set 4 | kuandian
# Processing Record 7 of Set 4 | kaihua
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | umm lajj
# Processing Record 10 of Set 4 | nylstroom
# City not found. Skipping...
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | temiscaming
# Processing Record 14 of Set 4 | bueno brandao
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | moree
# Processing Record 17 of Set 4 | gisborne
# Processing Record 18 of Set 4 | waipawa
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | tupik
# Processing Record 21 of Set 4 | byron bay
# Processing Record 22 of Set 4 | rio gallegos
# Processing Record 23 of Set 4 | kurumkan
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | hirara
# Processing Record 26 of Set 4 | jinchang
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | fatehgarh
# Processing Record 29 of Set 4 | boysun
# Processing Record 30 of Set 4 | ostrovnoy
# Processing Record 31 of Set 4 | eyl
# Processing Record 32 of Set 4 | taltal
# Processing Record 33 of Set 4 | ormara
# Processing Record 34 of Set 4 | westport
# Processing Record 35 of Set 4 | stornoway
# Processing Record 36 of Set 4 | victor harbor
# Processing Record 37 of Set 4 | laguna
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | khiri mat
# Processing Record 40 of Set 4 | sonda
# Processing Record 41 of Set 4 | hambantota
# Processing Record 42 of Set 4 | paita
# Processing Record 43 of Set 4 | ust-nera
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | klaksvik
# Processing Record 46 of Set 4 | alzamay
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | kambove
# Processing Record 49 of Set 4 | olinda
# Processing Record 50 of Set 4 | shihezi
# Processing Record 1 of Set 5 | colesberg
# Processing Record 2 of Set 5 | saldanha
# Processing Record 3 of Set 5 | khandyga
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | asau
# Processing Record 6 of Set 5 | macapa
# Processing Record 7 of Set 5 | chimbote
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | nokha
# Processing Record 12 of Set 5 | zheleznodorozhnyy
# Processing Record 13 of Set 5 | berdigestyakh
# Processing Record 14 of Set 5 | umm kaddadah
# Processing Record 15 of Set 5 | aykhal
# Processing Record 16 of Set 5 | los banos
# Processing Record 17 of Set 5 | nara
# Processing Record 18 of Set 5 | vostok
# Processing Record 19 of Set 5 | mongo
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | urubicha
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | poum
# Processing Record 24 of Set 5 | puerto del rosario
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | alofi
# Processing Record 27 of Set 5 | epe
# Processing Record 28 of Set 5 | luziania
# Processing Record 29 of Set 5 | champoton
# Processing Record 30 of Set 5 | tukums
# Processing Record 31 of Set 5 | camacha
# Processing Record 32 of Set 5 | urumqi
# Processing Record 33 of Set 5 | uvinza
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | kaka
# Processing Record 37 of Set 5 | susurluk
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | ust-maya
# Processing Record 40 of Set 5 | rancho palos verdes
# Processing Record 41 of Set 5 | jiayuguan
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | barrow
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | daru
# Processing Record 46 of Set 5 | saint anthony
# Processing Record 47 of Set 5 | kalaleh
# Processing Record 48 of Set 5 | grajau
# Processing Record 49 of Set 5 | jablah
# Processing Record 50 of Set 5 | moa
# Processing Record 1 of Set 6 | taguatinga
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | villa union
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | remontnoye
# Processing Record 6 of Set 6 | havre
# Processing Record 7 of Set 6 | carballo
# Processing Record 8 of Set 6 | tallahassee
# Processing Record 9 of Set 6 | brigantine
# Processing Record 10 of Set 6 | strezhevoy
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | torrington
# Processing Record 13 of Set 6 | myanaung
# Processing Record 14 of Set 6 | phuket
# Processing Record 15 of Set 6 | thompson
# Processing Record 16 of Set 6 | ponta do sol
# Processing Record 17 of Set 6 | vestmannaeyjar
# Processing Record 18 of Set 6 | teknaf
# Processing Record 19 of Set 6 | port elizabeth
# Processing Record 20 of Set 6 | martapura
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | vanavara
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | puerto cabello
# Processing Record 25 of Set 6 | pedasi
# Processing Record 26 of Set 6 | kewanee
# Processing Record 27 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 6 | ayan
# Processing Record 29 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 6 | kutum
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 6 | sulejowek
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | ishigaki
# Processing Record 35 of Set 6 | springbok
# Processing Record 36 of Set 6 | cockburn town
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | harlingen
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | harlow
# Processing Record 41 of Set 6 | zogno
# Processing Record 42 of Set 6 | tevaitoa
# Processing Record 43 of Set 6 | malangali
# Processing Record 44 of Set 6 | shelburne
# Processing Record 45 of Set 6 | thunder bay
# Processing Record 46 of Set 6 | yerbogachen
# Processing Record 47 of Set 6 | neiafu
# Processing Record 48 of Set 6 | carutapera
# Processing Record 49 of Set 6 | batagay-alyta
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 7 | te anau
# Processing Record 2 of Set 7 | bethel
# Processing Record 3 of Set 7 | tiznit
# Processing Record 4 of Set 7 | kavieng
# Processing Record 5 of Set 7 | shepetivka
# Processing Record 6 of Set 7 | ojinaga
# Processing Record 7 of Set 7 | lakhimpur
# Processing Record 8 of Set 7 | touros
# Processing Record 9 of Set 7 | baykit
# Processing Record 10 of Set 7 | tura
# Processing Record 11 of Set 7 | torbay
# Processing Record 12 of Set 7 | safita
# Processing Record 13 of Set 7 | leninsk
# Processing Record 14 of Set 7 | santa isabel do rio negro
# Processing Record 15 of Set 7 | gillette
# Processing Record 16 of Set 7 | coahuayana
# Processing Record 17 of Set 7 | san luis
# Processing Record 18 of Set 7 | necochea
# Processing Record 19 of Set 7 | srednekolymsk
# Processing Record 20 of Set 7 | ode
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | ponta delgada
# Processing Record 23 of Set 7 | moroni
# Processing Record 24 of Set 7 | wesselsbron
# Processing Record 25 of Set 7 | arman
# Processing Record 26 of Set 7 | winslow
# Processing Record 27 of Set 7 | detva
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | lakselv
# Processing Record 30 of Set 7 | havoysund
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | sitka
# Processing Record 33 of Set 7 | slobozia
# Processing Record 34 of Set 7 | el naranjo
# Processing Record 35 of Set 7 | bantou
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | imbituba
# Processing Record 38 of Set 7 | ulaanbaatar
# Processing Record 39 of Set 7 | surin
# Processing Record 40 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 43 of Set 7 | zhangye
# Processing Record 44 of Set 7 | qaqortoq
# Processing Record 45 of Set 7 | bulgan
# Processing Record 46 of Set 7 | sambava
# Processing Record 47 of Set 7 | kinablangan
# Processing Record 48 of Set 7 | inuvik
# Processing Record 49 of Set 7 | burica
# City not found. Skipping...
# Processing Record 50 of Set 7 | biltine
# Processing Record 1 of Set 8 | mitu
# Processing Record 2 of Set 8 | tahe
# Processing Record 3 of Set 8 | murray bridge
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 | bangassou
# Processing Record 6 of Set 8 | cajamarca
# Processing Record 7 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 8 of Set 8 | ixtapa
# Processing Record 9 of Set 8 | awbari
# Processing Record 10 of Set 8 | mitzic
# Processing Record 11 of Set 8 | litovko
# Processing Record 12 of Set 8 | ahome
# Processing Record 13 of Set 8 | saint-augustin
# Processing Record 14 of Set 8 | richards bay
# Processing Record 15 of Set 8 | pembroke
# Processing Record 16 of Set 8 | port-gentil
# Processing Record 17 of Set 8 | ankara
# Processing Record 18 of Set 8 | iracoubo
# Processing Record 19 of Set 8 | tabou
# Processing Record 20 of Set 8 | merauke
# Processing Record 21 of Set 8 | valdivia
# Processing Record 22 of Set 8 | hongjiang
# Processing Record 23 of Set 8 | beira
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | maryville
# Processing Record 26 of Set 8 | baikunthpur
# Processing Record 27 of Set 8 | san patricio
# Processing Record 28 of Set 8 | madingou
# Processing Record 29 of Set 8 | kumbo
# Processing Record 30 of Set 8 | huilong
# Processing Record 31 of Set 8 | karangasem
# Processing Record 32 of Set 8 | florianopolis
# Processing Record 33 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 8 | konstantinovka
# Processing Record 35 of Set 8 | gilbues
# Processing Record 36 of Set 8 | pong
# Processing Record 37 of Set 8 | pochutla
# Processing Record 38 of Set 8 | naze
# Processing Record 39 of Set 8 | rodrigues alves
# Processing Record 40 of Set 8 | presidencia roque saenz pena
# Processing Record 41 of Set 8 | kimbe
# Processing Record 42 of Set 8 | poya
# Processing Record 43 of Set 8 | lavrentiya
# Processing Record 44 of Set 8 | spearfish
# Processing Record 45 of Set 8 | aracruz
# Processing Record 46 of Set 8 | tokmak
# Processing Record 47 of Set 8 | smithers
# Processing Record 48 of Set 8 | prince rupert
# Processing Record 49 of Set 8 | damphu
# Processing Record 50 of Set 8 | pangody
# Processing Record 1 of Set 9 | oro valley
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | katsuura
# Processing Record 4 of Set 9 | san rafael del sur
# Processing Record 5 of Set 9 | makinsk
# Processing Record 6 of Set 9 | raton
# Processing Record 7 of Set 9 | coihaique
# Processing Record 8 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 9 | koygorodok
# Processing Record 10 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | seryshevo
# Processing Record 12 of Set 9 | slantsy
# Processing Record 13 of Set 9 | gidam
# Processing Record 14 of Set 9 | mumford
# Processing Record 15 of Set 9 | mormugao
# Processing Record 16 of Set 9 | sol-iletsk
# Processing Record 17 of Set 9 | sangar
# Processing Record 18 of Set 9 | saint-pierre
# Processing Record 19 of Set 9 | petropavl
# Processing Record 20 of Set 9 | belgrade
# Processing Record 21 of Set 9 | parkes
# Processing Record 22 of Set 9 | manaskent
# Processing Record 23 of Set 9 | temple
# Processing Record 24 of Set 9 | sinop
# Processing Record 25 of Set 9 | jiuquan
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | gamba
# Processing Record 28 of Set 9 | vawkavysk
# Processing Record 29 of Set 9 | nishihara
# Processing Record 30 of Set 9 | singaraja
# Processing Record 31 of Set 9 | constantine
# Processing Record 32 of Set 9 | launceston
# Processing Record 33 of Set 9 | luanda
# Processing Record 34 of Set 9 | caconda
# Processing Record 35 of Set 9 | cascais
# Processing Record 36 of Set 9 | ipixuna
# Processing Record 37 of Set 9 | nichinan
# Processing Record 38 of Set 9 | griffith
# Processing Record 39 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 9 | chernyshevskiy
# Processing Record 41 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 9 | saint-francois
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | hofu
# Processing Record 45 of Set 9 | muisne
# Processing Record 46 of Set 9 | port hardy
# Processing Record 47 of Set 9 | jalu
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 50 of Set 9 | kasempa
# Processing Record 1 of Set 10 | jumla
# Processing Record 2 of Set 10 | praya
# Processing Record 3 of Set 10 | fairbanks
# Processing Record 4 of Set 10 | grants
# Processing Record 5 of Set 10 | rameshki
# Processing Record 6 of Set 10 | anastacio
# Processing Record 7 of Set 10 | zhanaozen
# Processing Record 8 of Set 10 | belmonte
# Processing Record 9 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 10 | paamiut
# Processing Record 11 of Set 10 | waitati
# Processing Record 12 of Set 10 | domoni
# Processing Record 13 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 10 | hearst
# Processing Record 15 of Set 10 | hualmay
# Processing Record 16 of Set 10 | bedele
# Processing Record 17 of Set 10 | marmora
# Processing Record 18 of Set 10 | mahebourg
# Processing Record 19 of Set 10 | lata
# Processing Record 20 of Set 10 | manado
# Processing Record 21 of Set 10 | mananara
# Processing Record 22 of Set 10 | krasnoselkup
# Processing Record 23 of Set 10 | coreau
# Processing Record 24 of Set 10 | bereda
# Processing Record 25 of Set 10 | kerema
# Processing Record 26 of Set 10 | hami
# Processing Record 27 of Set 10 | langres
# Processing Record 28 of Set 10 | nantucket
# Processing Record 29 of Set 10 | gombong
# Processing Record 30 of Set 10 | vallenar
# Processing Record 31 of Set 10 | sandnessjoen
# Processing Record 32 of Set 10 | zyryanovsk
# Processing Record 33 of Set 10 | pemberton
# Processing Record 34 of Set 10 | lompoc
# Processing Record 35 of Set 10 | salina cruz
# Processing Record 36 of Set 10 | perth
# Processing Record 37 of Set 10 | gazojak
# Processing Record 38 of Set 10 | salmas
# Processing Record 39 of Set 10 | celestun
# Processing Record 40 of Set 10 | turayf
# Processing Record 41 of Set 10 | leningradskiy
# Processing Record 42 of Set 10 | menongue
# Processing Record 43 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 10 | joao pinheiro
# Processing Record 45 of Set 10 | san cristobal
# Processing Record 46 of Set 10 | thenzawl
# Processing Record 47 of Set 10 | aksarka
# Processing Record 48 of Set 10 | metro
# Processing Record 49 of Set 10 | gizo
# Processing Record 50 of Set 10 | tomatlan
# Processing Record 1 of Set 11 | lorengau
# Processing Record 2 of Set 11 | lahad datu
# Processing Record 3 of Set 11 | rocha
# Processing Record 4 of Set 11 | morant bay
# Processing Record 5 of Set 11 | pala
# Processing Record 6 of Set 11 | henties bay
# Processing Record 7 of Set 11 | saint george
# Processing Record 8 of Set 11 | ranong
# Processing Record 9 of Set 11 | mocuba
# Processing Record 10 of Set 11 | agucadoura
# Processing Record 11 of Set 11 | rio grande
# Processing Record 12 of Set 11 | amapa
# Processing Record 13 of Set 11 | maniitsoq
# Processing Record 14 of Set 11 | palana
# Processing Record 15 of Set 11 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 11 | grahamstown
# Processing Record 17 of Set 11 | tautira
# Processing Record 18 of Set 11 | veraval
# Processing Record 19 of Set 11 | mikhaylovka
# Processing Record 20 of Set 11 | businga
# Processing Record 21 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 22 of Set 11 | havre-saint-pierre
# Processing Record 23 of Set 11 | ketchikan
# Processing Record 24 of Set 11 | yandyki
# Processing Record 25 of Set 11 | hobyo
# Processing Record 26 of Set 11 | bubaque
# Processing Record 27 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 11 | adrar
# Processing Record 29 of Set 11 | antigonish
# Processing Record 30 of Set 11 | port hawkesbury
# Processing Record 31 of Set 11 | kargasok
# Processing Record 32 of Set 11 | norman wells
# Processing Record 33 of Set 11 | baiyin
# Processing Record 34 of Set 11 | nanlong
# Processing Record 35 of Set 11 | marabba
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 38 of Set 11 | wakkanai
# Processing Record 39 of Set 11 | safaga
# Processing Record 40 of Set 11 | uvalde
# Processing Record 41 of Set 11 | bluefields
# Processing Record 42 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 11 | abu kamal
# Processing Record 44 of Set 11 | ballyshannon
# Processing Record 45 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 11 | kokopo
# Processing Record 48 of Set 11 | wajir
# Processing Record 49 of Set 11 | paterno
# Processing Record 50 of Set 11 | aitape
# Processing Record 1 of Set 12 | sturgeon falls
# Processing Record 2 of Set 12 | pisco
# Processing Record 3 of Set 12 | beruwala
# Processing Record 4 of Set 12 | douglas
# Processing Record 5 of Set 12 | vondrozo
# Processing Record 6 of Set 12 | ulladulla
# Processing Record 7 of Set 12 | zyryanka
# Processing Record 8 of Set 12 | langxiang
# Processing Record 9 of Set 12 | kisangani
# Processing Record 10 of Set 12 | matata
# Processing Record 11 of Set 12 | lohja
# Processing Record 12 of Set 12 | ca mau
# Processing Record 13 of Set 12 | dakar
# Processing Record 14 of Set 12 | garowe
# Processing Record 15 of Set 12 | axim
# Processing Record 16 of Set 12 | kiama
# Processing Record 17 of Set 12 | broome
# Processing Record 18 of Set 12 | port macquarie
# Processing Record 19 of Set 12 | kindu
# Processing Record 20 of Set 12 | wajima
# Processing Record 21 of Set 12 | guerrero negro
# Processing Record 22 of Set 12 | kupang
# Processing Record 23 of Set 12 | akyab
# Processing Record 24 of Set 12 | shingu
# Processing Record 25 of Set 12 | mombetsu
# Processing Record 26 of Set 12 | disna
# Processing Record 27 of Set 12 | tezu
# Processing Record 28 of Set 12 | dekar
# Processing Record 29 of Set 12 | juneau
# Processing Record 30 of Set 12 | athabasca
# Processing Record 31 of Set 12 | porto tolle
# Processing Record 32 of Set 12 | pareora
# Processing Record 33 of Set 12 | roma
# Processing Record 34 of Set 12 | ryotsu
# Processing Record 35 of Set 12 | taunggyi
# Processing Record 36 of Set 12 | san quintin
# Processing Record 37 of Set 12 | khasan
# Processing Record 38 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 12 | chimore
# Processing Record 40 of Set 12 | barrhead
# Processing Record 41 of Set 12 | kingston
# Processing Record 42 of Set 12 | kotido
# Processing Record 43 of Set 12 | wattegama
# Processing Record 44 of Set 12 | hofn
# Processing Record 45 of Set 12 | nairobi
# Processing Record 46 of Set 12 | komatipoort
# Processing Record 47 of Set 12 | cuamba
# Processing Record 48 of Set 12 | nogliki
# Processing Record 49 of Set 12 | mingaora
# Processing Record 50 of Set 12 | usakos
# Processing Record 1 of Set 13 | yulara
# Processing Record 2 of Set 13 | makakilo city
# Processing Record 3 of Set 13 | bathsheba
# Processing Record 4 of Set 13 | palmas
# Processing Record 5 of Set 13 | zhetybay
# City not found. Skipping...
# Processing Record 6 of Set 13 | nikel
# Processing Record 7 of Set 13 | hervey bay
# Processing Record 8 of Set 13 | trebinje
# Processing Record 9 of Set 13 | bay roberts
# Processing Record 10 of Set 13 | north bend
# Processing Record 11 of Set 13 | flinders
# Processing Record 12 of Set 13 | vrangel
# Processing Record 13 of Set 13 | mareeba
# Processing Record 14 of Set 13 | yatou
# Processing Record 15 of Set 13 | atambua
# Processing Record 16 of Set 13 | sherbakul
# Processing Record 17 of Set 13 | ewa beach
# Processing Record 18 of Set 13 | auki
# Processing Record 19 of Set 13 | puri
# Processing Record 20 of Set 13 | sorong
# Processing Record 21 of Set 13 | alyangula
# Processing Record 22 of Set 13 | castletown
# Processing Record 23 of Set 13 | port lincoln
# Processing Record 24 of Set 13 | alipur chatha
# Processing Record 25 of Set 13 | vanderhoof
# Processing Record 26 of Set 13 | sorland
# Processing Record 27 of Set 13 | whyalla
# Processing Record 28 of Set 13 | finschhafen
# Processing Record 29 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 13 | wuchang
# Processing Record 31 of Set 13 | whitstable
# Processing Record 32 of Set 13 | concepcion del oro
# Processing Record 33 of Set 13 | kushima
# Processing Record 34 of Set 13 | taoudenni
# Processing Record 35 of Set 13 | isla mujeres
# Processing Record 36 of Set 13 | nuuk
# Processing Record 37 of Set 13 | januaria
# Processing Record 38 of Set 13 | natal
# Processing Record 39 of Set 13 | robertsport
# Processing Record 40 of Set 13 | zacatepec
# Processing Record 41 of Set 13 | djenne
# Processing Record 42 of Set 13 | listowel
# Processing Record 43 of Set 13 | jiexiu
# Processing Record 44 of Set 13 | ecoporanga
# Processing Record 45 of Set 13 | salalah
# Processing Record 46 of Set 13 | pitimbu
# Processing Record 47 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 13 | beringovskiy
# Processing Record 49 of Set 13 | kamalganj
# Processing Record 50 of Set 13 | kipushi
# Processing Record 1 of Set 14 | tongzi
# Processing Record 2 of Set 14 | nago
# Processing Record 3 of Set 14 | nabire
# Processing Record 4 of Set 14 | lensk
# Processing Record 5 of Set 14 | ganzhou
# Processing Record 6 of Set 14 | umarkot
# Processing Record 7 of Set 14 | chicama
# Processing Record 8 of Set 14 | palmer
# Processing Record 9 of Set 14 | jawhar
# Processing Record 10 of Set 14 | waldshut-tiengen
# Processing Record 11 of Set 14 | millet
# Processing Record 12 of Set 14 | birjand
# Processing Record 13 of Set 14 | muswellbrook
# Processing Record 14 of Set 14 | masunga
# Processing Record 15 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 14 | pierre
# Processing Record 17 of Set 14 | mansa
# Processing Record 18 of Set 14 | komsomolskiy
# Processing Record 19 of Set 14 | bijie
# Processing Record 20 of Set 14 | vao
# Processing Record 21 of Set 14 | tual
# Processing Record 22 of Set 14 | maputo
# Processing Record 23 of Set 14 | tayu
# Processing Record 24 of Set 14 | homer
# Processing Record 25 of Set 14 | uribia
# Processing Record 26 of Set 14 | bagan
# Processing Record 27 of Set 14 | kamenka
# Processing Record 28 of Set 14 | dwarka
# Processing Record 29 of Set 14 | santarem
# Processing Record 30 of Set 14 | lakes entrance
# Processing Record 31 of Set 14 | madera
# Processing Record 32 of Set 14 | dalby
# Processing Record 33 of Set 14 | union city
# Processing Record 34 of Set 14 | muros
# Processing Record 35 of Set 14 | quang ngai
# Processing Record 36 of Set 14 | ahipara
# Processing Record 37 of Set 14 | sangmelima
# Processing Record 38 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 14 | kyshtovka
# Processing Record 40 of Set 14 | goure
# Processing Record 41 of Set 14 | lake charles
# Processing Record 42 of Set 14 | maragogi
# Processing Record 43 of Set 14 | shimoda
# Processing Record 44 of Set 14 | madoc
# Processing Record 45 of Set 14 | raudeberg
# Processing Record 46 of Set 14 | ibotirama
# Processing Record 47 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 14 | agstafa
# City not found. Skipping...
# Processing Record 49 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 14 | marquette
# Processing Record 1 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 2 of Set 15 | barpathar
# Processing Record 3 of Set 15 | angoche
# Processing Record 4 of Set 15 | victoria point
# Processing Record 5 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 15 | lander
# Processing Record 8 of Set 15 | ambon
# Processing Record 9 of Set 15 | pak thong chai
# Processing Record 10 of Set 15 | nizwa
# Processing Record 11 of Set 15 | harper
# Processing Record 12 of Set 15 | sabang
# Processing Record 13 of Set 15 | kuminskiy
# Processing Record 14 of Set 15 | mogadishu
# Processing Record 15 of Set 15 | flin flon
# Processing Record 16 of Set 15 | petukhovo
# Processing Record 17 of Set 15 | kharp
# Processing Record 18 of Set 15 | jatibarang
# Processing Record 19 of Set 15 | ekhabi
# Processing Record 20 of Set 15 | berlevag
# Processing Record 21 of Set 15 | trelew
# Processing Record 22 of Set 15 | igdir
# Processing Record 23 of Set 15 | beisfjord
# Processing Record 24 of Set 15 | anadyr
# Processing Record 25 of Set 15 | terrace
# Processing Record 26 of Set 15 | nautla
# Processing Record 27 of Set 15 | shiyan
# Processing Record 28 of Set 15 | coquimbo
# Processing Record 29 of Set 15 | itapira
# Processing Record 30 of Set 15 | hovd
# Processing Record 31 of Set 15 | angatuba
# Processing Record 32 of Set 15 | grindavik
# Processing Record 33 of Set 15 | ibra
# Processing Record 34 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 15 | hatillo
# Processing Record 36 of Set 15 | puerto montt
# Processing Record 37 of Set 15 | afsin
# Processing Record 38 of Set 15 | kjollefjord
# Processing Record 39 of Set 15 | moscow
# Processing Record 40 of Set 15 | hai phong
# City not found. Skipping...
# Processing Record 41 of Set 15 | caxito
# Processing Record 42 of Set 15 | weiser
# Processing Record 43 of Set 15 | creston
# Processing Record 44 of Set 15 | grants pass
# Processing Record 45 of Set 15 | nargana
# Processing Record 46 of Set 15 | serowe
# Processing Record 47 of Set 15 | south river
# Processing Record 48 of Set 15 | turukhansk
# Processing Record 49 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 50 of Set 15 | damietta
# Processing Record 1 of Set 16 | bozoum
# Processing Record 2 of Set 16 | fowa
# Processing Record 3 of Set 16 | plettenberg bay
# Processing Record 4 of Set 16 | spornoye
# Processing Record 5 of Set 16 | soe
# Processing Record 6 of Set 16 | altay
# Processing Record 7 of Set 16 | bilibino
# Processing Record 8 of Set 16 | sarangani
# Processing Record 9 of Set 16 | mount gambier
# Processing Record 10 of Set 16 | magam
# Processing Record 11 of Set 16 | ferrol
# Processing Record 12 of Set 16 | ransang
# Processing Record 13 of Set 16 | abashiri
# Processing Record 14 of Set 16 | santa luzia
# Processing Record 15 of Set 16 | nanortalik
# Processing Record 16 of Set 16 | paragominas
# Processing Record 17 of Set 16 | huarmey
# Processing Record 18 of Set 16 | madison heights
# Processing Record 19 of Set 16 | benghazi
# Processing Record 20 of Set 16 | kitui
# Processing Record 21 of Set 16 | peniche
# Processing Record 22 of Set 16 | xiazhen
# Processing Record 23 of Set 16 | tarbes
# Processing Record 24 of Set 16 | rundu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown      US  42.0970  -79.2353     70.84        94           0
# 1    Mar Del Plata      AR -38.0023  -57.5575     53.49        87           0
# 2            Pilar      BR  -9.5972  -35.9567     68.81        94          42
# 3          College      US  64.8569 -147.8028     55.65        50          24
# 4           Castro      BR -24.7911  -50.0119     57.83        98         100
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     69.64        93         100
# 6          Kahului      US  20.8947 -156.4700     80.96        78          99
# 7            Kapaa      US  22.0752 -159.3190     80.11        59         100
# 8       High Level      CA  58.5169 -117.1360     52.36        55         100
# 9      East London      ZA -33.0153   27.9116     57.27        59          42
#
#    Wind Speed Current Description
# 0        5.77           clear sky
# 1       10.16           clear sky
# 2        2.08    scattered clouds
# 3        1.01          few clouds
# 4        3.74     overcast clouds
# 5       13.29     overcast clouds
# 6       14.43     overcast clouds
# 7        4.00     overcast clouds
# 8        9.69     overcast clouds
# 9        2.28    scattered clouds

# %%
# Create the output file (CSV) and export

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
