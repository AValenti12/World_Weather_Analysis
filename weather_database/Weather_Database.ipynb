# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Identify the nearest city for each latitude and longitude combination.

coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 760

# %%
#Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
#starting URL for weathing map api call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3b3ab0f8a745015731d3dfe5180b08e2

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | yulara
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | ilheus
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | rocha
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | mocuba
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | kulhudhuffushi
# Processing Record 15 of Set 1 | lagoa
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | san luis
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | ponta pora
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | klaksvik
# Processing Record 31 of Set 1 | doctor arroyo
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | daugavpils
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | rorvik
# Processing Record 36 of Set 1 | tommot
# Processing Record 37 of Set 1 | nouadhibou
# Processing Record 38 of Set 1 | mangrol
# Processing Record 39 of Set 1 | halifax
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | itarema
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | nizhniy odes
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | sinnamary
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | port hardy
# Processing Record 50 of Set 1 | bathurst
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | impfondo
# Processing Record 5 of Set 2 | coahuayana
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | batsfjord
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | san carlos
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | karratha
# Processing Record 17 of Set 2 | kabinda
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 2 | havoysund
# Processing Record 22 of Set 2 | ambilobe
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | broken hill
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | imeni zhelyabova
# Processing Record 28 of Set 2 | brae
# Processing Record 29 of Set 2 | rio gallegos
# Processing Record 30 of Set 2 | fairbanks
# Processing Record 31 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 2 | paamiut
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | wajima
# Processing Record 35 of Set 2 | sungaipenuh
# Processing Record 36 of Set 2 | cockburn town
# Processing Record 37 of Set 2 | poum
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | havre-saint-pierre
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | pacific grove
# Processing Record 44 of Set 2 | valparaiso
# Processing Record 45 of Set 2 | bourail
# Processing Record 46 of Set 2 | lebanon
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | tabou
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | rabo de peixe
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | kenai
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | vinukonda
# Processing Record 11 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 14 of Set 3 | peniche
# Processing Record 15 of Set 3 | solnechnyy
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | basco
# Processing Record 18 of Set 3 | hauknes
# Processing Record 19 of Set 3 | laa
# Processing Record 20 of Set 3 | srednekolymsk
# Processing Record 21 of Set 3 | loei
# Processing Record 22 of Set 3 | adre
# Processing Record 23 of Set 3 | antofagasta
# Processing Record 24 of Set 3 | albemarle
# Processing Record 25 of Set 3 | clonakilty
# Processing Record 26 of Set 3 | pinawa
# Processing Record 27 of Set 3 | touzim
# Processing Record 28 of Set 3 | nyrob
# Processing Record 29 of Set 3 | nampula
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | nainpur
# Processing Record 32 of Set 3 | mehamn
# Processing Record 33 of Set 3 | batagay
# Processing Record 34 of Set 3 | sosua
# Processing Record 35 of Set 3 | vardo
# Processing Record 36 of Set 3 | svetlaya
# Processing Record 37 of Set 3 | hakvik
# City not found. Skipping...
# Processing Record 38 of Set 3 | kerema
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | xai-xai
# Processing Record 41 of Set 3 | taldan
# Processing Record 42 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 3 | wexford
# Processing Record 44 of Set 3 | kuryk
# Processing Record 45 of Set 3 | najran
# Processing Record 46 of Set 3 | khani
# Processing Record 47 of Set 3 | espirito santo do pinhal
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 3 | alpena
# Processing Record 1 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 4 | umm lajj
# Processing Record 5 of Set 4 | strezhevoy
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | eldorado
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | barao de cocais
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | la paz
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | neiafu
# Processing Record 14 of Set 4 | buraydah
# Processing Record 15 of Set 4 | ola
# Processing Record 16 of Set 4 | beringovskiy
# Processing Record 17 of Set 4 | vrangel
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | kieta
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | pringsewu
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | nantucket
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | santa rosa
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | forbes
# Processing Record 29 of Set 4 | ritchie
# Processing Record 30 of Set 4 | linares
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | kenora
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | koumac
# Processing Record 35 of Set 4 | komsomolskiy
# Processing Record 36 of Set 4 | alofi
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | tarragona
# Processing Record 39 of Set 4 | hovd
# Processing Record 40 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 4 | andra
# Processing Record 42 of Set 4 | jos
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | aklavik
# Processing Record 45 of Set 4 | flin flon
# Processing Record 46 of Set 4 | malkapur
# Processing Record 47 of Set 4 | fortuna
# Processing Record 48 of Set 4 | boa vista
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | belvedere marittimo
# Processing Record 1 of Set 5 | mezen
# Processing Record 2 of Set 5 | aktau
# Processing Record 3 of Set 5 | marzuq
# Processing Record 4 of Set 5 | liwale
# Processing Record 5 of Set 5 | vestmannaeyjar
# Processing Record 6 of Set 5 | jimani
# Processing Record 7 of Set 5 | doha
# Processing Record 8 of Set 5 | bloomington
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | udachnyy
# Processing Record 12 of Set 5 | nikolskoye
# Processing Record 13 of Set 5 | ilebo
# Processing Record 14 of Set 5 | zaranj
# Processing Record 15 of Set 5 | nagato
# Processing Record 16 of Set 5 | mercedes
# Processing Record 17 of Set 5 | betafo
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | seddon
# Processing Record 21 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 5 | cabedelo
# Processing Record 23 of Set 5 | martapura
# Processing Record 24 of Set 5 | dikson
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | balingasay
# Processing Record 27 of Set 5 | yefimovskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | okhotsk
# Processing Record 30 of Set 5 | zyryanka
# Processing Record 31 of Set 5 | mao
# Processing Record 32 of Set 5 | beloha
# Processing Record 33 of Set 5 | grand baie
# Processing Record 34 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 5 | kombissiri
# Processing Record 37 of Set 5 | bereda
# Processing Record 38 of Set 5 | balikpapan
# Processing Record 39 of Set 5 | tautira
# Processing Record 40 of Set 5 | longyearbyen
# Processing Record 41 of Set 5 | gat
# Processing Record 42 of Set 5 | gedo
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | kaniama
# Processing Record 45 of Set 5 | zhireken
# Processing Record 46 of Set 5 | ewa beach
# Processing Record 47 of Set 5 | portland
# Processing Record 48 of Set 5 | dingle
# Processing Record 49 of Set 5 | mahebourg
# Processing Record 50 of Set 5 | lyngseidet
# Processing Record 1 of Set 6 | grand gaube
# Processing Record 2 of Set 6 | college
# Processing Record 3 of Set 6 | sosva
# Processing Record 4 of Set 6 | morehead
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | chicama
# Processing Record 7 of Set 6 | omboue
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | souillac
# Processing Record 10 of Set 6 | inirida
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | atar
# Processing Record 13 of Set 6 | kuah
# Processing Record 14 of Set 6 | almazar
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | chifeng
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | palu
# Processing Record 19 of Set 6 | mattru
# Processing Record 20 of Set 6 | sao geraldo do araguaia
# Processing Record 21 of Set 6 | balad
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | stawell
# Processing Record 24 of Set 6 | rayong
# Processing Record 25 of Set 6 | kununurra
# Processing Record 26 of Set 6 | kirkuk
# Processing Record 27 of Set 6 | kapuskasing
# Processing Record 28 of Set 6 | coihaique
# Processing Record 29 of Set 6 | nianzishan
# Processing Record 30 of Set 6 | sayyan
# Processing Record 31 of Set 6 | anju
# Processing Record 32 of Set 6 | san jeronimo
# Processing Record 33 of Set 6 | kahului
# Processing Record 34 of Set 6 | armidale
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | byron bay
# Processing Record 37 of Set 6 | bandarbeyla
# Processing Record 38 of Set 6 | paita
# Processing Record 39 of Set 6 | dalvik
# Processing Record 40 of Set 6 | naryan-mar
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | araouane
# Processing Record 43 of Set 6 | clyde river
# Processing Record 44 of Set 6 | namatanai
# Processing Record 45 of Set 6 | parrsboro
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | pavlodar
# Processing Record 48 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 6 | izumo
# Processing Record 50 of Set 6 | mangaratiba
# Processing Record 1 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 7 | mandeville
# Processing Record 3 of Set 7 | alpinopolis
# Processing Record 4 of Set 7 | nguruka
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | lukovetskiy
# Processing Record 7 of Set 7 | camacupa
# Processing Record 8 of Set 7 | beira
# Processing Record 9 of Set 7 | himora
# City not found. Skipping...
# Processing Record 10 of Set 7 | kyshtovka
# Processing Record 11 of Set 7 | harqalah
# Processing Record 12 of Set 7 | hecelchakan
# Processing Record 13 of Set 7 | marawi
# Processing Record 14 of Set 7 | zambezi
# Processing Record 15 of Set 7 | namibe
# Processing Record 16 of Set 7 | terpni
# Processing Record 17 of Set 7 | ahipara
# Processing Record 18 of Set 7 | gondanglegi
# Processing Record 19 of Set 7 | alice springs
# Processing Record 20 of Set 7 | novikovo
# Processing Record 21 of Set 7 | auki
# Processing Record 22 of Set 7 | sao filipe
# Processing Record 23 of Set 7 | eyl
# Processing Record 24 of Set 7 | evensk
# Processing Record 25 of Set 7 | ingham
# Processing Record 26 of Set 7 | helong
# Processing Record 27 of Set 7 | lufkin
# Processing Record 28 of Set 7 | saint-joseph
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | necochea
# Processing Record 31 of Set 7 | chirongui
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | leua
# Processing Record 34 of Set 7 | fukue
# Processing Record 35 of Set 7 | burica
# City not found. Skipping...
# Processing Record 36 of Set 7 | sola
# Processing Record 37 of Set 7 | maracaibo
# Processing Record 38 of Set 7 | chenghai
# Processing Record 39 of Set 7 | makungu
# Processing Record 40 of Set 7 | vulturu
# Processing Record 41 of Set 7 | fort nelson
# Processing Record 42 of Set 7 | nome
# Processing Record 43 of Set 7 | sarkand
# Processing Record 44 of Set 7 | cayenne
# Processing Record 45 of Set 7 | timra
# Processing Record 46 of Set 7 | pahrump
# Processing Record 47 of Set 7 | soverato
# Processing Record 48 of Set 7 | highland springs
# Processing Record 49 of Set 7 | erdaojiang
# Processing Record 50 of Set 7 | reo
# Processing Record 1 of Set 8 | payo
# Processing Record 2 of Set 8 | rostovka
# Processing Record 3 of Set 8 | manokwari
# Processing Record 4 of Set 8 | arlit
# Processing Record 5 of Set 8 | san pedro
# Processing Record 6 of Set 8 | oranjemund
# Processing Record 7 of Set 8 | tripoli
# Processing Record 8 of Set 8 | gimli
# Processing Record 9 of Set 8 | port hedland
# Processing Record 10 of Set 8 | timizart
# Processing Record 11 of Set 8 | ayagoz
# Processing Record 12 of Set 8 | rajanpur
# Processing Record 13 of Set 8 | vila franca do campo
# Processing Record 14 of Set 8 | cape coast
# Processing Record 15 of Set 8 | banjar
# Processing Record 16 of Set 8 | ugoofaaru
# Processing Record 17 of Set 8 | machesney park
# Processing Record 18 of Set 8 | faanui
# Processing Record 19 of Set 8 | gold coast
# Processing Record 20 of Set 8 | belyy yar
# Processing Record 21 of Set 8 | hami
# Processing Record 22 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 8 | lexington
# Processing Record 24 of Set 8 | cabra
# Processing Record 25 of Set 8 | bitung
# Processing Record 26 of Set 8 | padang
# Processing Record 27 of Set 8 | taltal
# Processing Record 28 of Set 8 | ecoporanga
# Processing Record 29 of Set 8 | bonavista
# Processing Record 30 of Set 8 | mogocha
# Processing Record 31 of Set 8 | asyut
# Processing Record 32 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 8 | taywarah
# Processing Record 34 of Set 8 | zhirnovsk
# Processing Record 35 of Set 8 | galveston
# Processing Record 36 of Set 8 | rio rancho
# Processing Record 37 of Set 8 | tarpon springs
# Processing Record 38 of Set 8 | saskylakh
# Processing Record 39 of Set 8 | kamina
# Processing Record 40 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 8 | galle
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | port-cartier
# Processing Record 44 of Set 8 | kingisepp
# Processing Record 45 of Set 8 | tornio
# Processing Record 46 of Set 8 | dalbandin
# Processing Record 47 of Set 8 | grand-santi
# Processing Record 48 of Set 8 | guane
# Processing Record 49 of Set 8 | aksarka
# Processing Record 50 of Set 8 | amuntai
# Processing Record 1 of Set 9 | vytegra
# Processing Record 2 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 9 | krasnoselkup
# Processing Record 4 of Set 9 | derbent
# Processing Record 5 of Set 9 | palmer
# Processing Record 6 of Set 9 | darhan
# Processing Record 7 of Set 9 | potam
# Processing Record 8 of Set 9 | vanimo
# Processing Record 9 of Set 9 | aquiraz
# Processing Record 10 of Set 9 | sinjai
# Processing Record 11 of Set 9 | kharp
# Processing Record 12 of Set 9 | katobu
# Processing Record 13 of Set 9 | sorkjosen
# Processing Record 14 of Set 9 | douglas
# Processing Record 15 of Set 9 | nakamura
# Processing Record 16 of Set 9 | dharchula
# Processing Record 17 of Set 9 | tiznit
# Processing Record 18 of Set 9 | akyab
# Processing Record 19 of Set 9 | xichang
# Processing Record 20 of Set 9 | tromso
# Processing Record 21 of Set 9 | kaabong
# Processing Record 22 of Set 9 | vaitape
# Processing Record 23 of Set 9 | korsakovo
# Processing Record 24 of Set 9 | guarda
# Processing Record 25 of Set 9 | huajuapan
# City not found. Skipping...
# Processing Record 26 of Set 9 | vilyuysk
# Processing Record 27 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 9 | jumla
# Processing Record 29 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 9 | lodja
# Processing Record 31 of Set 9 | shuangcheng
# Processing Record 32 of Set 9 | formiga
# Processing Record 33 of Set 9 | karasburg
# Processing Record 34 of Set 9 | chor
# Processing Record 35 of Set 9 | bilma
# Processing Record 36 of Set 9 | kumba
# Processing Record 37 of Set 9 | esmeraldas
# Processing Record 38 of Set 9 | mazagao
# Processing Record 39 of Set 9 | batasan
# Processing Record 40 of Set 9 | sweetwater
# Processing Record 41 of Set 9 | geraldton
# Processing Record 42 of Set 9 | berlevag
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | riyadh
# Processing Record 46 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 47 of Set 9 | maniitsoq
# Processing Record 48 of Set 9 | axim
# Processing Record 49 of Set 9 | conceicao do araguaia
# Processing Record 50 of Set 9 | plainview
# Processing Record 1 of Set 10 | airai
# Processing Record 2 of Set 10 | yangambi
# Processing Record 3 of Set 10 | stornoway
# Processing Record 4 of Set 10 | baturaja
# Processing Record 5 of Set 10 | bathsheba
# Processing Record 6 of Set 10 | sambava
# Processing Record 7 of Set 10 | luganville
# Processing Record 8 of Set 10 | aranos
# Processing Record 9 of Set 10 | olga
# Processing Record 10 of Set 10 | ust-shonosha
# Processing Record 11 of Set 10 | kupino
# Processing Record 12 of Set 10 | sitka
# Processing Record 13 of Set 10 | makakilo city
# Processing Record 14 of Set 10 | sorland
# Processing Record 15 of Set 10 | kirkwall
# Processing Record 16 of Set 10 | shorewood
# Processing Record 17 of Set 10 | gamba
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 20 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 21 of Set 10 | constantine
# Processing Record 22 of Set 10 | budogoshch
# Processing Record 23 of Set 10 | erdenet
# Processing Record 24 of Set 10 | recreio
# Processing Record 25 of Set 10 | klimovo
# Processing Record 26 of Set 10 | tarko-sale
# Processing Record 27 of Set 10 | kerrville
# Processing Record 28 of Set 10 | monrovia
# Processing Record 29 of Set 10 | norman wells
# Processing Record 30 of Set 10 | marsabit
# Processing Record 31 of Set 10 | tilichiki
# Processing Record 32 of Set 10 | sur
# Processing Record 33 of Set 10 | verkhnevilyuysk
# Processing Record 34 of Set 10 | mawlaik
# Processing Record 35 of Set 10 | leshukonskoye
# Processing Record 36 of Set 10 | luanda
# Processing Record 37 of Set 10 | qasigiannguit
# Processing Record 38 of Set 10 | lasa
# Processing Record 39 of Set 10 | asau
# Processing Record 40 of Set 10 | kalabo
# Processing Record 41 of Set 10 | salym
# Processing Record 42 of Set 10 | llano de piedra
# Processing Record 43 of Set 10 | turukhansk
# Processing Record 44 of Set 10 | caravelas
# Processing Record 45 of Set 10 | aykhal
# Processing Record 46 of Set 10 | dongsheng
# Processing Record 47 of Set 10 | dutse
# Processing Record 48 of Set 10 | melfi
# Processing Record 49 of Set 10 | plettenberg bay
# Processing Record 50 of Set 10 | kloulklubed
# Processing Record 1 of Set 11 | belaya gora
# Processing Record 2 of Set 11 | pangnirtung
# Processing Record 3 of Set 11 | soe
# Processing Record 4 of Set 11 | coetupo
# City not found. Skipping...
# Processing Record 5 of Set 11 | smithers
# Processing Record 6 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 11 | gisborne
# Processing Record 8 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | maracai
# Processing Record 10 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | deputatskiy
# Processing Record 13 of Set 11 | zhigansk
# Processing Record 14 of Set 11 | troitskoye
# Processing Record 15 of Set 11 | gualeguaychu
# Processing Record 16 of Set 11 | grand island
# Processing Record 17 of Set 11 | erenhot
# Processing Record 18 of Set 11 | mandera
# Processing Record 19 of Set 11 | qaqortoq
# Processing Record 20 of Set 11 | taksimo
# Processing Record 21 of Set 11 | paoua
# Processing Record 22 of Set 11 | sandakan
# Processing Record 23 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 11 | kilifi
# Processing Record 25 of Set 11 | alta floresta
# Processing Record 26 of Set 11 | rawah
# Processing Record 27 of Set 11 | acapulco
# Processing Record 28 of Set 11 | viransehir
# Processing Record 29 of Set 11 | cururupu
# Processing Record 30 of Set 11 | la tuque
# Processing Record 31 of Set 11 | umred
# Processing Record 32 of Set 11 | kavaratti
# Processing Record 33 of Set 11 | zabid
# Processing Record 34 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of Set 11 | san buenaventura
# Processing Record 36 of Set 11 | sotnikovskoye
# Processing Record 37 of Set 11 | kochinda
# Processing Record 38 of Set 11 | laguna
# Processing Record 39 of Set 11 | domna
# Processing Record 40 of Set 11 | san jose de guanipa
# Processing Record 41 of Set 11 | sinazongwe
# Processing Record 42 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 11 | kirakira
# Processing Record 44 of Set 11 | yumen
# Processing Record 45 of Set 11 | salisbury
# Processing Record 46 of Set 11 | saint george
# Processing Record 47 of Set 11 | evreux
# Processing Record 48 of Set 11 | molina
# Processing Record 49 of Set 11 | luxor
# Processing Record 50 of Set 11 | tecoanapa
# Processing Record 1 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 12 | mbandaka
# Processing Record 3 of Set 12 | loukhi
# Processing Record 4 of Set 12 | demirci
# Processing Record 5 of Set 12 | esperance
# Processing Record 6 of Set 12 | hare bay
# Processing Record 7 of Set 12 | magaramkent
# Processing Record 8 of Set 12 | praia da vitoria
# Processing Record 9 of Set 12 | manaus
# Processing Record 10 of Set 12 | pilar
# Processing Record 11 of Set 12 | liverpool
# Processing Record 12 of Set 12 | dapaong
# Processing Record 13 of Set 12 | egvekinot
# Processing Record 14 of Set 12 | ostrovnoy
# Processing Record 15 of Set 12 | flagstaff
# Processing Record 16 of Set 12 | tsiroanomandidy
# Processing Record 17 of Set 12 | northam
# Processing Record 18 of Set 12 | graham
# Processing Record 19 of Set 12 | kamaishi
# Processing Record 20 of Set 12 | kavieng
# Processing Record 21 of Set 12 | mana
# Processing Record 22 of Set 12 | kysyl-syr
# Processing Record 23 of Set 12 | kodinsk
# Processing Record 24 of Set 12 | san cristobal
# Processing Record 25 of Set 12 | mumias
# Processing Record 26 of Set 12 | korogwe
# City not found. Skipping...
# Processing Record 27 of Set 12 | whitehorse
# Processing Record 28 of Set 12 | trincomalee
# Processing Record 29 of Set 12 | ortakoy
# Processing Record 30 of Set 12 | la orilla
# Processing Record 31 of Set 12 | christchurch
# Processing Record 32 of Set 12 | mindelo
# Processing Record 33 of Set 12 | sangar
# Processing Record 34 of Set 12 | asfi
# Processing Record 35 of Set 12 | tabas
# Processing Record 36 of Set 12 | biharamulo
# Processing Record 37 of Set 12 | luz
# Processing Record 38 of Set 12 | karcag
# Processing Record 39 of Set 12 | irece
# Processing Record 40 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 41 of Set 12 | texarkana
# Processing Record 42 of Set 12 | narwar
# Processing Record 43 of Set 12 | bembereke
# Processing Record 44 of Set 12 | codrington
# Processing Record 45 of Set 12 | ust-ilimsk
# Processing Record 46 of Set 12 | bonthe
# Processing Record 47 of Set 12 | meadow lake
# Processing Record 48 of Set 12 | oussouye
# Processing Record 49 of Set 12 | semnan
# Processing Record 50 of Set 12 | ust-tsilma
# Processing Record 1 of Set 13 | shimoda
# Processing Record 2 of Set 13 | zhezkazgan
# Processing Record 3 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 13 | adrar
# Processing Record 5 of Set 13 | chernyshevskiy
# Processing Record 6 of Set 13 | benguela
# Processing Record 7 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 13 | abu samrah
# Processing Record 9 of Set 13 | shelburne
# Processing Record 10 of Set 13 | novyy urengoy
# Processing Record 11 of Set 13 | yerofey pavlovich
# Processing Record 12 of Set 13 | san quintin
# Processing Record 13 of Set 13 | san patricio
# Processing Record 14 of Set 13 | fayaoue
# Processing Record 15 of Set 13 | sydney
# Processing Record 16 of Set 13 | pestretsy
# Processing Record 17 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 18 of Set 13 | yenagoa
# Processing Record 19 of Set 13 | ust-kuyga
# Processing Record 20 of Set 13 | esik
# Processing Record 21 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 13 | gatesville
# Processing Record 24 of Set 13 | rock sound
# Processing Record 25 of Set 13 | menongue
# Processing Record 26 of Set 13 | shaoyang
# Processing Record 27 of Set 13 | kiama
# Processing Record 28 of Set 13 | muroran
# Processing Record 29 of Set 13 | san jose
# Processing Record 30 of Set 13 | naze
# Processing Record 31 of Set 13 | vila velha
# Processing Record 32 of Set 13 | clevelandia
# Processing Record 33 of Set 13 | wajir
# Processing Record 34 of Set 13 | flinders
# Processing Record 35 of Set 13 | buzmeyin
# Processing Record 36 of Set 13 | aljezur
# Processing Record 37 of Set 13 | saint-pierre
# Processing Record 38 of Set 13 | correntina
# Processing Record 39 of Set 13 | pitman
# Processing Record 40 of Set 13 | new albany
# Processing Record 41 of Set 13 | lagunas
# Processing Record 42 of Set 13 | fairfield
# Processing Record 43 of Set 13 | mandalgovi
# Processing Record 44 of Set 13 | acajutla
# Processing Record 45 of Set 13 | elko
# Processing Record 46 of Set 13 | mogadishu
# Processing Record 47 of Set 13 | sept-iles
# Processing Record 48 of Set 13 | puerto leguizamo
# Processing Record 49 of Set 13 | mazatlan
# Processing Record 50 of Set 13 | rondonopolis
# Processing Record 1 of Set 14 | nizwa
# Processing Record 2 of Set 14 | rundu
# Processing Record 3 of Set 14 | camana
# Processing Record 4 of Set 14 | riberalta
# Processing Record 5 of Set 14 | vagur
# Processing Record 6 of Set 14 | houma
# Processing Record 7 of Set 14 | dahod
# Processing Record 8 of Set 14 | adamovka
# Processing Record 9 of Set 14 | muros
# Processing Record 10 of Set 14 | itatinga
# Processing Record 11 of Set 14 | apaxco
# City not found. Skipping...
# Processing Record 12 of Set 14 | moussoro
# Processing Record 13 of Set 14 | agadez
# Processing Record 14 of Set 14 | mosquera
# Processing Record 15 of Set 14 | kashi
# Processing Record 16 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 17 of Set 14 | kaohsiung
# Processing Record 18 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | luwingu
# Processing Record 20 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 14 | pandan
# Processing Record 22 of Set 14 | madang
# Processing Record 23 of Set 14 | quballat
# Processing Record 24 of Set 14 | nizhniy tsasuchey
# Processing Record 25 of Set 14 | ampanihy
# Processing Record 26 of Set 14 | sabzevar
# Processing Record 27 of Set 14 | asifabad
# Processing Record 28 of Set 14 | moose factory
# Processing Record 29 of Set 14 | khasan
# Processing Record 30 of Set 14 | aripuana
# Processing Record 31 of Set 14 | vao
# Processing Record 32 of Set 14 | guanica
# Processing Record 33 of Set 14 | kushiro
# Processing Record 34 of Set 14 | ziro
# Processing Record 35 of Set 14 | inuvik
# Processing Record 36 of Set 14 | salinopolis
# Processing Record 37 of Set 14 | penha
# Processing Record 38 of Set 14 | alyangula
# Processing Record 39 of Set 14 | turbat
# Processing Record 40 of Set 14 | lenki
# City not found. Skipping...
# Processing Record 41 of Set 14 | pozo colorado
# Processing Record 42 of Set 14 | marsh harbour
# Processing Record 43 of Set 14 | tagusao
# Processing Record 44 of Set 14 | sibolga
# Processing Record 45 of Set 14 | margate
# Processing Record 46 of Set 14 | det udom
# Processing Record 47 of Set 14 | labuhan
# Processing Record 48 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 14 | anito
# Processing Record 50 of Set 14 | tokur
# Processing Record 1 of Set 15 | coffs harbour
# Processing Record 2 of Set 15 | zhongshu
# Processing Record 3 of Set 15 | alexandria
# Processing Record 4 of Set 15 | quatre cocos
# Processing Record 5 of Set 15 | novyy buyan
# Processing Record 6 of Set 15 | lashio
# Processing Record 7 of Set 15 | marataizes
# Processing Record 8 of Set 15 | khartoum
# Processing Record 9 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 10 of Set 15 | maymyo
# Processing Record 11 of Set 15 | roma
# Processing Record 12 of Set 15 | qandala
# Processing Record 13 of Set 15 | beloit
# Processing Record 14 of Set 15 | haines junction
# Processing Record 15 of Set 15 | nieuw amsterdam
# Processing Record 16 of Set 15 | presidencia roque saenz pena
# Processing Record 17 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 18 of Set 15 | fort-shevchenko
# Processing Record 19 of Set 15 | iranshahr
# Processing Record 20 of Set 15 | ndele
# Processing Record 21 of Set 15 | clinton
# Processing Record 22 of Set 15 | stabat
# Processing Record 23 of Set 15 | bairiki
# Processing Record 24 of Set 15 | devarkonda
# Processing Record 25 of Set 15 | dicabisagan
# Processing Record 26 of Set 15 | abha
# Processing Record 27 of Set 15 | villazon
# Processing Record 28 of Set 15 | rakaia
# Processing Record 29 of Set 15 | lodwar
# Processing Record 30 of Set 15 | iralaya
# Processing Record 31 of Set 15 | cairns
# Processing Record 32 of Set 15 | koulikoro
# Processing Record 33 of Set 15 | san carlos de bariloche
# Processing Record 34 of Set 15 | eureka
# Processing Record 35 of Set 15 | sterling
# Processing Record 36 of Set 15 | biak
# Processing Record 37 of Set 15 | juneau
# Processing Record 38 of Set 15 | oktyabrskiy
# Processing Record 39 of Set 15 | yabrud
# Processing Record 40 of Set 15 | pop
# Processing Record 41 of Set 15 | khandyga
# Processing Record 42 of Set 15 | hastings
# Processing Record 43 of Set 15 | butte
# Processing Record 44 of Set 15 | syracuse
# Processing Record 45 of Set 15 | batagay-alyta
# Processing Record 46 of Set 15 | constitucion
# Processing Record 47 of Set 15 | qom
# Processing Record 48 of Set 15 | walvis bay
# Processing Record 49 of Set 15 | baljevac
# Processing Record 50 of Set 15 | celestun
# Processing Record 1 of Set 16 | pemba
# Processing Record 2 of Set 16 | papara
# Processing Record 3 of Set 16 | xifeng
# Processing Record 4 of Set 16 | puri
# Processing Record 5 of Set 16 | lagos
# Processing Record 6 of Set 16 | amapa
# Processing Record 7 of Set 16 | lulea
# Processing Record 8 of Set 16 | rennes
# Processing Record 9 of Set 16 | kalulushi
# Processing Record 10 of Set 16 | osoyoos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     48.47        70         100
# 1          Yulara      AU -25.2406  130.9889     73.54        30           0
# 2  Cabo San Lucas      MX  22.8909 -109.9124     92.61        74          20
# 3          Ilheus      BR -14.7889  -39.0494     69.55        82          12
# 4         Ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 5            Hilo      US  19.7297 -155.0900     80.62        69          30
# 6           Rocha      UY -34.4833  -54.3333     54.95        98           2
# 7       Jamestown      US  42.0970  -79.2353     65.52        89           1
# 8         Rikitea      PF -23.1203 -134.9692     72.95        75           9
# 9      Chokurdakh      RU  70.6333  147.9167     34.90        59          37
#
#    Wind Speed Current Description
# 0        5.32          light rain
# 1       14.05           clear sky
# 2        8.05          few clouds
# 3        3.00          few clouds
# 4        3.44           clear sky
# 5        3.00          light rain
# 6        5.73           clear sky
# 7        1.99           clear sky
# 8        7.34           clear sky
# 9        6.78    scattered clouds

# %%
len(city_data)
# Out:
# 699

# %%
# Create the output file (CSV) and export

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     48.47        70         100
# 1          Yulara      AU -25.2406  130.9889     73.54        30           0
# 2  Cabo San Lucas      MX  22.8909 -109.9124     92.61        74          20
# 3          Ilheus      BR -14.7889  -39.0494     69.55        82          12
# 4         Ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 5            Hilo      US  19.7297 -155.0900     80.62        69          30
# 6           Rocha      UY -34.4833  -54.3333     54.95        98           2
# 7       Jamestown      US  42.0970  -79.2353     65.52        89           1
# 8         Rikitea      PF -23.1203 -134.9692     72.95        75           9
# 9      Chokurdakh      RU  70.6333  147.9167     34.90        59          37
#
#    Wind Speed Current Description
# 0        5.32          light rain
# 1       14.05           clear sky
# 2        8.05          few clouds
# 3        3.00          few clouds
# 4        3.44           clear sky
# 5        3.00          light rain
# 6        5.73           clear sky
# 7        1.99           clear sky
# 8        7.34           clear sky
# 9        6.78    scattered clouds
